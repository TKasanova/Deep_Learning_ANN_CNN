# %% [markdown]
# # Classification

# %% [markdown]
# <span class="girk">We have a dataset in which there are details of a bank's customers and the target variable is a binary variable reflecting the fact whether the customer left the bank (closed his account) or he continues to be a customer.</span>

# %% [markdown]
# ![binary.png](attachment:binary.png)

# %% [markdown]
# ## Import  libraries & data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
# %matplotlib notebook
plt.rcParams["figure.figsize"] = (12, 6)
# plt.rcParams['figure.dpi'] = 100
sns.set_style("whitegrid")
import warnings

warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\ktahi\anaconda3\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ktahi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.41.2)
# Requirement already satisfied: rich in c:\users\ktahi\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\ktahi\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\ktahi\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ktahi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ktahi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ktahi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ktahi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ktahi\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ktahi\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\ktahi\anaconda3\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ktahi\anaconda3\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ktahi\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.0)

# %%
# ilgili kütüphanelerin tümü
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, average_precision_score
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("Churn_Modelling.csv", index_col='RowNumber')
df.head()
#Tenure:Number of years for which the customer has been with the bank
#NumOfProducts :Number of bank products the customer is utilising
#Binary flag 1 if the customer closed account with bank and 0 if the customer is retained
#"RowNumber" sütunu indeks olarak belirleniyor
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1              0.000              1          1               1
# 2          83807.860              1          0               1
# 3         159660.800              3          1               0
# 4              0.000              2          0               0
# 5         125510.820              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1               101348.880       1
# 2               112542.580       0
# 3               113931.570       1
# 4                93826.630       0
# 5                79084.100       0

# %% [markdown]
# ![churn.JPG](attachment:churn.JPG)

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.isnull().sum().any()
# Out:
# False

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                     count         mean       std          min          25%  \
# CustomerId      10000.000 15690940.569 71936.186 15565701.000 15628528.250
# CreditScore     10000.000      650.529    96.653      350.000      584.000
# Age             10000.000       38.922    10.488       18.000       32.000
# Tenure          10000.000        5.013     2.892        0.000        3.000
# Balance         10000.000    76485.889 62397.405        0.000        0.000
# NumOfProducts   10000.000        1.530     0.582        1.000        1.000
# HasCrCard       10000.000        0.706     0.456        0.000        0.000
# IsActiveMember  10000.000        0.515     0.500        0.000        0.000
# EstimatedSalary 10000.000   100090.240 57510.493       11.580    51002.110
# Exited          10000.000        0.204     0.403        0.000        0.000
#
#                          50%          75%          max
# CustomerId      15690738.000 15753233.750 15815690.000
# CreditScore          652.000      718.000      850.000
# Age                   37.000       44.000       92.000
# Tenure                 5.000        7.000       10.000
# Balance            97198.540   127644.240   250898.090
# NumOfProducts          1.000        2.000        4.000
# HasCrCard              1.000        1.000        1.000
# IsActiveMember         1.000        1.000        1.000
# EstimatedSalary   100193.915   149388.247   199992.480
# Exited                 0.000        0.000        1.000

# %%
df.drop(['CustomerId', 'Surname'], axis=1, inplace=True)

# %%
df.Exited.value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
value_counts = df['Exited'].value_counts()

plt.bar(value_counts.index, value_counts.values);

# %%
df.hist(figsize=(15, 12), bins=15);

# %%
numerical_df = df.select_dtypes(include=[np.number])
plt.figure(figsize=(16, 12))
sns.heatmap(numerical_df.corr(), annot=True, cmap='viridis')
# Out:
# <Axes: >

# %%
# yukarıda ki kodda hata alanlar alt satırda ki kodu çalıştırsın

# %%
numerical_df = df.select_dtypes(include=[np.number])
correlation_series = numerical_df.corr()['Exited'][:-1].sort_values()
correlation_series.plot.barh();

# %%
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#            CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# RowNumber
# 1                  619   42       2      0.000              1          1
# 2                  608   41       1  83807.860              1          0
# 3                  502   42       8 159660.800              3          1
# 4                  699   39       1      0.000              2          0
# 5                  850   43       2 125510.820              1          1
#
#            IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# RowNumber
# 1                       1       101348.880       1              False
# 2                       1       112542.580       0              False
# 3                       0       113931.570       1              False
# 4                       0        93826.630       0              False
# 5                       1        79084.100       0              False
#
#            Geography_Spain  Gender_Male
# RowNumber
# 1                    False        False
# 2                     True        False
# 3                    False        False
# 4                    False        False
# 5                     True        False

# %% [markdown]
# ## Preprocessing of Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
X = df.drop('Exited', axis=1)
y = df['Exited'].values
seed = 42
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    stratify=y,
                                                    test_size=0.1,
                                                    random_state=seed)

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ![Structure-of-machine-learning-model.png](attachment:Structure-of-machine-learning-model.png)

# %% [markdown]
# ## Modelling & Model Performance

# %% [markdown]
# ### without class_weigth

# %%
X_train.shape
# Out:
# (9000, 11)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, BatchNormalization
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score

# %%
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

model.add(Dense(64, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(32, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(1, activation="sigmoid"))

opt = Adam(learning_rate=0.002)
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])

# Recall — the percentage of positive cases you caught
# Recall, false negative’in gözardı edilemez olduğu durumlarda önemli bir metrik. recall = TP / TP +FN
# Recall’a bakma sebebimiz tamamiyle paydadaki false negative’ler, yani hesabına devam ettiği tahmin edilen ve hesabını kapatan insanlar.
# cok katmanlilarda batchnormalizatipn yapmak daha iyi score cikartmaya yonelik

# %%
early_stop = EarlyStopping(monitor="val_loss",
                           mode="auto",
                           verbose=1,
                           patience=90)

# %%
model.fit(x=X_train,
          y=y_train,
          validation_split=.1,
          batch_size=128,
          epochs=500,
          verbose=1,
          callbacks=[early_stop])
# Out:
# Epoch 1/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - Recall: 0.2883 - loss: 0.6399 - val_Recall: 0.0055 - val_loss: 0.4702
# Epoch 2/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.2127 - loss: 0.4489 - val_Recall: 0.3260 - val_loss: 0.3820
# Epoch 3/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.2967 - loss: 0.4086 - val_Recall: 0.5083 - val_loss: 0.3422
# Epoch 4/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.3570 - loss: 0.3890 - val_Recall: 0.4751 - val_loss: 0.3307
# Epoch 5/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.3891 - loss: 0.3911 - val_Recall: 0.5470 - val_loss: 0.3060
# Epoch 6/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.4153 - loss: 0.3678 - val_Recall: 0.5304 - val_loss: 0.3090
# Epoch 7/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.4294 - loss: 0.3570 - val_Recall: 0.5691 - val_loss: 0.3135
# Epoch 8/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.4159 - loss: 0.3538 - val_Recall: 0.5138 - val_loss: 0.3019
# Epoch 9/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.4042 - loss: 0.3585 - val_Recall: 0.5470 - val_loss: 0.2918
# Epoch 10/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.4207 - loss: 0.3660 - val_Recall: 0.5912 - val_loss: 0.3057
# Epoch 11/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4428 - loss: 0.3595 - val_Recall: 0.5580 - val_loss: 0.2974
# Epoch 12/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.4590 - loss: 0.3601 - val_Recall: 0.4641 - val_loss: 0.3186
# Epoch 13/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4145 - loss: 0.3578 - val_Recall: 0.6243 - val_loss: 0.3029
# Epoch 14/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4611 - loss: 0.3487 - val_Recall: 0.4088 - val_loss: 0.3143
# Epoch 15/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4297 - loss: 0.3333 - val_Recall: 0.6298 - val_loss: 0.3122
# Epoch 16/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4266 - loss: 0.3547 - val_Recall: 0.5359 - val_loss: 0.3109
# Epoch 17/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4522 - loss: 0.3472 - val_Recall: 0.5470 - val_loss: 0.3123
# Epoch 18/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4411 - loss: 0.3440 - val_Recall: 0.5359 - val_loss: 0.3060
# Epoch 19/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4637 - loss: 0.3383 - val_Recall: 0.5414 - val_loss: 0.3095
# Epoch 20/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.4626 - loss: 0.3311 - val_Recall: 0.5801 - val_loss: 0.2850
# Epoch 21/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4718 - loss: 0.3486 - val_Recall: 0.5138 - val_loss: 0.3049
# Epoch 22/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4664 - loss: 0.3366 - val_Recall: 0.5083 - val_loss: 0.3212
# Epoch 23/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4606 - loss: 0.3470 - val_Recall: 0.5359 - val_loss: 0.3032
# Epoch 24/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4318 - loss: 0.3423 - val_Recall: 0.5470 - val_loss: 0.3034
# Epoch 25/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4659 - loss: 0.3335 - val_Recall: 0.5580 - val_loss: 0.3089
# Epoch 26/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4396 - loss: 0.3430 - val_Recall: 0.5580 - val_loss: 0.2967
# Epoch 27/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4505 - loss: 0.3394 - val_Recall: 0.5138 - val_loss: 0.3138
# Epoch 28/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4393 - loss: 0.3378 - val_Recall: 0.5691 - val_loss: 0.3007
# Epoch 29/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4610 - loss: 0.3418 - val_Recall: 0.4641 - val_loss: 0.3088
# Epoch 30/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4622 - loss: 0.3453 - val_Recall: 0.5967 - val_loss: 0.3007
# Epoch 31/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.4662 - loss: 0.3306 - val_Recall: 0.5470 - val_loss: 0.3044
# Epoch 32/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5313 - loss: 0.3003 - val_Recall: 0.5028 - val_loss: 0.3486
# Epoch 88/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5160 - loss: 0.3055 - val_Recall: 0.5856 - val_loss: 0.3247
# Epoch 89/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5778 - loss: 0.2896 - val_Recall: 0.5525 - val_loss: 0.3316
# Epoch 90/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5341 - loss: 0.3082 - val_Recall: 0.5028 - val_loss: 0.3507
# Epoch 91/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5172 - loss: 0.3022 - val_Recall: 0.4917 - val_loss: 0.3396
# Epoch 92/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5162 - loss: 0.3046 - val_Recall: 0.5028 - val_loss: 0.3450
# Epoch 93/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5301 - loss: 0.3100 - val_Recall: 0.4807 - val_loss: 0.3535
# Epoch 94/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5469 - loss: 0.2986 - val_Recall: 0.5249 - val_loss: 0.3314
# Epoch 95/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5179 - loss: 0.3060 - val_Recall: 0.5304 - val_loss: 0.3351
# Epoch 96/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5301 - loss: 0.3202 - val_Recall: 0.5193 - val_loss: 0.3423
# Epoch 97/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5480 - loss: 0.3015 - val_Recall: 0.5249 - val_loss: 0.3276
# Epoch 98/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5356 - loss: 0.2989 - val_Recall: 0.5801 - val_loss: 0.3271
# Epoch 99/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5663 - loss: 0.2884 - val_Recall: 0.5028 - val_loss: 0.3413
# Epoch 100/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5467 - loss: 0.3064 - val_Recall: 0.4972 - val_loss: 0.3360
# Epoch 101/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5228 - loss: 0.2980 - val_Recall: 0.5359 - val_loss: 0.3443
# Epoch 102/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5376 - loss: 0.2887 - val_Recall: 0.5525 - val_loss: 0.3548
# Epoch 103/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5859 - loss: 0.2883 - val_Recall: 0.5304 - val_loss: 0.3570
# Epoch 104/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5600 - loss: 0.2925 - val_Recall: 0.4917 - val_loss: 0.3657
# Epoch 105/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5273 - loss: 0.3079 - val_Recall: 0.5525 - val_loss: 0.3284
# Epoch 106/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5499 - loss: 0.3014 - val_Recall: 0.5801 - val_loss: 0.3335
# Epoch 107/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5499 - loss: 0.2960 - val_Recall: 0.5083 - val_loss: 0.3399
# Epoch 108/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5419 - loss: 0.2946 - val_Recall: 0.5304 - val_loss: 0.3414
# Epoch 109/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5330 - loss: 0.3012 - val_Recall: 0.5138 - val_loss: 0.3352
# Epoch 110/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5325 - loss: 0.3032 - val_Recall: 0.5691 - val_loss: 0.3288
# Epoch 110: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 8)                   │              32 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,341 (48.21 KB)
#  Trainable params: 4,033 (15.75 KB)
#  Non-trainable params: 240 (960.00 B)
#  Optimizer params: 8,068 (31.52 KB)

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.head()
# Out:
#    Recall  loss  val_Recall  val_loss
# 0   0.216 0.550       0.006     0.470
# 1   0.232 0.437       0.326     0.382
# 2   0.318 0.400       0.508     0.342
# 3   0.364 0.387       0.475     0.331
# 4   0.386 0.378       0.547     0.306

# %%
loss_df.plot()
# Out:
# <Axes: >

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# [[754  42]
#  [105  99]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91       796
#            1       0.70      0.49      0.57       204
#
#     accuracy                           0.85      1000
#    macro avg       0.79      0.72      0.74      1000
# weighted avg       0.84      0.85      0.84      1000

# %% [markdown]
# ![ROC.JPG](attachment:ROC.JPG)

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for model

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# roc curve, sınıflandırma performansını gösterir
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.6671848185372699

# %% [markdown]
# ### with class_weigth

# %%
model = Sequential()

model.add(Dense(64, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(32, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(1, activation="sigmoid"))

opt = Adam(learning_rate=0.002)
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                  classes=np.unique(y_train),
                                                  y=y_train)

class_weights = {0: class_weights[0], 1: class_weights[1]}
class_weights
# Out:
# {0: 0.6278777731268314, 1: 2.454991816693944}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model.fit(x=X_train,
          y=y_train,
          validation_split=.1,
          batch_size=32,
          epochs=500,
          verbose=1,
          callbacks=[early_stop],
          class_weight=class_weights)
# Out:
# Epoch 1/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - Recall: 0.6493 - loss: 0.7394 - val_Recall: 0.5249 - val_loss: 0.6251
# Epoch 2/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.6407 - loss: 0.6077 - val_Recall: 0.7459 - val_loss: 0.5182
# Epoch 3/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.7063 - loss: 0.5476 - val_Recall: 0.8066 - val_loss: 0.4731
# Epoch 4/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.7583 - loss: 0.5313 - val_Recall: 0.7956 - val_loss: 0.5002
# Epoch 5/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7397 - loss: 0.5254 - val_Recall: 0.7569 - val_loss: 0.4110
# Epoch 6/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.8045 - loss: 0.4136 - val_Recall: 0.7459 - val_loss: 0.4308
# Epoch 89/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.8269 - loss: 0.4123 - val_Recall: 0.7238 - val_loss: 0.4264
# Epoch 90/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.8145 - loss: 0.3976 - val_Recall: 0.7569 - val_loss: 0.4359
# Epoch 90: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <Axes: >

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# [[628 168]
#  [ 45 159]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.79      0.86       796
#            1       0.49      0.78      0.60       204
#
#     accuracy                           0.79      1000
#    macro avg       0.71      0.78      0.73      1000
# weighted avg       0.84      0.79      0.80      1000

# %% [markdown]
# ![ROC.JPG](attachment:ROC.JPG)

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for model

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# roc curve, sınıflandırma performansını gösterir
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
average_precision_score(y_test, y_pred_proba)   #0.692983743350624
# Out:
# 0.666022169353896

# %% [markdown]
# ![model.jpeg](attachment:model.jpeg)

# %% [markdown]
# ## Final Model and Model Deployment

# %%
import pickle

pickle.dump(scaler, open("scaler_churn", 'wb'))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
scaler = MinMaxScaler().fit(X)

# %%
X_scaled = scaler.transform(X)

# %%
model = Sequential()

model.add(Dense(64, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(32, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(1, activation="sigmoid"))

opt = Adam(learning_rate=0.001)

model.compile(optimizer=opt,
              loss="binary_crossentropy",
              metrics=["Recall"])

# %%
model.fit(x=X_scaled,
          y=y,
          callbacks=[early_stop],
          batch_size=32,
          validation_split = 0.1,
          epochs=500,
          verbose=1,
          class_weight=class_weights)
# Out:
# Epoch 1/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - Recall: 0.6444 - loss: 0.7534 - val_Recall: 0.5196 - val_loss: 0.6234
# Epoch 2/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.7093 - loss: 0.6589 - val_Recall: 0.6872 - val_loss: 0.5980
# Epoch 3/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.7239 - loss: 0.6092 - val_Recall: 0.6313 - val_loss: 0.5611
# Epoch 4/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.7142 - loss: 0.5762 - val_Recall: 0.6816 - val_loss: 0.5861
# Epoch 5/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.7220 - loss: 0.5585 - val_Recall: 0.6313 - val_loss: 0.5098
# Epoch 6/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.7615 - loss: 0.5270 - val_Recall: 0.7374 - val_loss: 0.5322
# Epoch 7/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.8151 - loss: 0.4021 - val_Recall: 0.6648 - val_loss: 0.5043
# Epoch 87/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.8107 - loss: 0.4115 - val_Recall: 0.6704 - val_loss: 0.4740
# Epoch 88/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.8278 - loss: 0.4072 - val_Recall: 0.6983 - val_loss: 0.4883
# Epoch 89/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.8069 - loss: 0.4105 - val_Recall: 0.7207 - val_loss: 0.4892
# Epoch 90/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.8067 - loss: 0.4131 - val_Recall: 0.7374 - val_loss: 0.5321
# Epoch 90: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <Axes: >

# %%
loss, recall = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("recall : ", recall)
# Out:
# loss :  0.43309980630874634
# recall :  0.8578431606292725

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# [[627 169]
#  [ 29 175]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.79      0.86       796
#            1       0.51      0.86      0.64       204
#
#     accuracy                           0.80      1000
#    macro avg       0.73      0.82      0.75      1000
# weighted avg       0.86      0.80      0.82      1000

# %%
from tensorflow.keras.saving import save_model

save_model(model, 'model_churn.keras')

# %% [markdown]
# ![What-is-Behavioral-Intent-Prediction.jpg](attachment:What-is-Behavioral-Intent-Prediction.jpg)

# %% [markdown]
# ### Prediction

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
single_customer = df.drop('Exited', axis=1).iloc[0]
single_customer
# Out:
# CreditScore                619
# Age                         42
# Tenure                       2
# Balance                  0.000
# NumOfProducts                1
# HasCrCard                    1
# IsActiveMember               1
# EstimatedSalary     101348.880
# Geography_Germany        False
# Geography_Spain          False
# Gender_Male              False
# Name: 1, dtype: object

# %%
single_customer = scaler.transform(single_customer.values.reshape(-1, 11))
single_customer
# Out:
# array([[0.538     , 0.32432432, 0.2       , 0.        , 0.        ,
#         1.        , 1.        , 0.50673489, 0.        , 0.        ,
#         0.        ]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y_pred =(model.predict(single_customer) > 0.5).astype("int32")
y_pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# array([[1]])

# %%
df["Exited"].iloc[0]
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Comparison with ML

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model=LogisticRegression(class_weight='balanced')
log_model.fit(X_train, y_train)
y_pred = log_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[558 238]
#  [ 66 138]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.70      0.79       796
#            1       0.37      0.68      0.48       204
#
#     accuracy                           0.70      1000
#    macro avg       0.63      0.69      0.63      1000
# weighted avg       0.79      0.70      0.72      1000

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(class_weight='balanced')
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[763  33]
#  [116  88]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       796
#            1       0.73      0.43      0.54       204
#
#     accuracy                           0.85      1000
#    macro avg       0.80      0.69      0.73      1000
# weighted avg       0.84      0.85      0.84      1000
